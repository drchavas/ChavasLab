# %% [markdown]
# # Jupyter tutorial for plotting remote netcdf data from NCAR RDA server
# Author: Dan Chavas, Purdue (2018)
# This is based off of Ryan Abernathey's [tutorial](https://rabernat.github.io/research_computing/intro-to-basemap.html)  on using Basemap in python -- thanks Ryan!

# %% [markdown]
# # Read NetCDF data directly from a remote source (i.e. NO need to download!) using OpenDAP and make a basic plot

# %% [markdown]
# Here's an example taken from the NOAA Wave Watch III website (http://polar.ncep.noaa.gov/waves/examples/usingpython.shtml).
#
# This example will read in a recent WW3 model and plot up the significant wave height: (NOTE: You must change the date below to something recent)

# %% [markdown]
# ## Import relevant packages

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
import numpy as np
from netCDF4 import Dataset,num2date,date2num
import subprocess
import os
import shutil
import tempfile
import gzip
import datetime
import argparse
# %matplotlib inline  #for jupyter notebook interface; comment out when running .py script (rather than .ipynb) 
import warnings
import matplotlib.cbook
warnings.filterwarnings("ignore",category=matplotlib.cbook.mplDeprecation)

import netCDF4
from datetime import datetime, timedelta
# from windspharm.standard import VectorWind
# from windspharm.tools import prep_data, recover_data, order_latdim

# %% [markdown]
# ## Read data directly from NCAR RDA

# %%
# set up the URL to access the data server.
# See the NCAR RDA for available options

## USER INPUT ########################################
yyyymm_in='201802'
ddhh_in='0306'
date_in='%s%s'%(yyyymm_in,ddhh_in)  # this needs to be a recent data since only recent models are available for download
var_in = 'Temperature_isobaric'
i_plev = -1   #in ERA-I, pressure levels go TOA --> surface; thus last entry = level closest to the surface
url='https://rda.ucar.edu/thredds/dodsC/files/e/ds627.0/ei.oper.an.pl/%s/ei.oper.an.pl.regn128sc.%s'%(yyyymm_in,date_in)
############################################################

print('Date = %s'%date_in)

# Extract the desired data
# The indexing into the data set used by netCDF4 is standard python indexing
file = netCDF4.Dataset(url)
lat  = file.variables['lat'][:]
lon  = file.variables['lon'][:]
plev  = file.variables['isobaric'][:]  #[hPa]
plev_in = plev[i_plev] #[hPa]
print('Pressure level = %i hPa'%plev_in)
data = file.variables[var_in][0,i_plev,:,:]  #dims = [time, plev, lat, lon]; "0" = first entry in dimension

print(file)    # this prints the contents of the file if you want to see what's inside
file.close()
# Out:
# Date = 2018020306
# Pressure level = 1000 hPa
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format DAP2):
#     Originating_or_generating_Center: European Centre for Medium Range Weather Forecasts (ECMWF) (RSMC)
#     Originating_or_generating_Subcenter: 0
#     GRIB_table_version: 0,128
#     file_format: GRIB-1
#     Conventions: CF-1.6
#     history: Read using CDM IOSP GribCollection v3
#     featureType: GRID
#     dimensions(sizes): isobaric(37), lat(256), lon(512), time(1)
#     variables(dimensions): int32 GaussianLatLon_Projection(), float32 lat(lat), float32 lon(lon), float64 reftime(), float64 time(time), float32 isobaric(isobaric), float32 Geopotential_isobaric(time,isobaric,lat,lon), float32 Temperature_isobaric(time,isobaric,lat,lon), float32 Specific_humidity_isobaric(time,isobaric,lat,lon), float32 Vertical_velocity_isobaric(time,isobaric,lat,lon), float32 Vorticity_relative_isobaric(time,isobaric,lat,lon), float32 Divergence_isobaric(time,isobaric,lat,lon), float32 Relative_humidity_isobaric(time,isobaric,lat,lon), float32 Ozone_mass_mixing_ratio_isobaric(time,isobaric,lat,lon), float32 Specific_cloud_liquid_water_content_isobaric(time,isobaric,lat,lon), float32 Specific_cloud_ice_water_content_isobaric(time,isobaric,lat,lon), float32 Cloud_cover_isobaric(time,isobaric,lat,lon), float32 Potential_vorticity_isobaric(time,isobaric,lat,lon)
#     groups:

# %% [markdown]
# ## Plot data

# %%
# set up the figure
plt.figure()

# Plot the field using Basemap.  Start with setting the map
# projection using the limits of the lat/lon data itself:
fig=plt.figure(figsize=(12, 8) )

# Miller projection:
m=Basemap(projection='mill',lat_ts=10,llcrnrlon=lon.min(), \
  urcrnrlon=lon.max(),llcrnrlat=lat.min(),urcrnrlat=lat.max(), \
  resolution='c')


# convert the lat/lon values to x/y projections.

x, y = m(*np.meshgrid(lon,lat))

# plot the field using the fast pcolormesh routine 
# set the colormap to jet.

m.pcolormesh(x,y,data,shading='flat',cmap=plt.cm.jet)
m.colorbar(location='right')

# Add a coastline and axis values.

m.drawcoastlines()
m.fillcontinents()
m.drawmapboundary()
m.drawparallels(np.arange(-90.,90.,30.),labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,60.),labels=[0,0,0,1])

# Add a colorbar and title, and then show the plot.

plt.title('Example 2: %i hPa temperature for %s, ERA-Interim (read directly from NCAR RDA!)'%(plev_in,mydate));

# %%
####################################
## Plotting parameters
lon_min_pl = 0
lon_max_pl = 360
lat_min_pl = -90
lat_max_pl = 90

##Define colors, colorbar
# data_min_pl = np.nanmin(data)
# data_max_pl = np.nanmax(data)
data_min_pl = 250
data_max_pl = 330
data_delt = (data_max_pl-data_min_pl)/20
N_colors = np.int16(((data_max_pl-data_min_pl)/data_delt)+1)
###################################

# set up the figure
plt.figure()
fig=plt.figure(figsize=(12, 8) )

# Plot the field using Basemap.  Start with setting the map
# projection using the limits of the lat/lon data itself:

# Miller projection:
m=Basemap(projection='mill',lat_ts=10,llcrnrlon=lon_min_pl, \
  urcrnrlon=lon_max_pl,llcrnrlat=lat_min_pl,urcrnrlat=lat_max_pl, \
  resolution='c')

## If desired, regrid data to regular coarse grid (e.g. for non-gridded data)
# dlon = 1.0  #[deg]
# dlat = dlon #[deg]
# lons_new=np.arange((180+dlon)*(2/dlon))*dlon-180.0
# lats_new=np.arange((90+dlat)*(2/dlat))*dlat-90.0
# #print(lons_new,lats_new)
# from matplotlib.mlab import griddata
# data_new = griddata(lon, lat, data, lons_new, lats_new, interp='linear')
# print(lons_new.shape,lats_new.shape,data_new.shape)
# lon = lons_new
# lat = lats_new
# data = data_new

# convert the lat/lon values to x/y projections for a Cartesian plot
x, y = m(*np.meshgrid(lon,lat))

## FIRST: TERRAIN (if you have it)
# delev = 200  #[m]
# elev_min = 400  #[m]
# elev_max = 5000  #[m]
# contour_vals = np.arange(elev_min,elev_max,delev)
# CS = m.contour(x, y, zsfc_new, contour_vals,
#                  colors='grey', linewidths=0.4  # negative contours will be dashed by default
#                  )
##Terrain contour labels (if desired)
# clevs = CS.levels[1::3]  #every 3rd level
# clevs = np.arange(1000,np.max(CS.levels),1000)
# plt.clabel(CS, clevs, inline=1, fontsize=10, fmt='%4i')

## SECOND: DATA
# plot the field using the fast pcolormesh routine 

# define the colormap -- discrete colorbar (https://stackoverflow.com/questions/14777066/matplotlib-discrete-colorbar)
cmap = plt.cm.jet
# extract all colors from the .jet map
cmaplist = [cmap(i) for i in range(cmap.N)]
# force the first color entry to be grey
#             cmaplist[0] = (.5,.5,.5,1.0)
# create the new map
cmap = cmap.from_list('Custom cmap', cmaplist, cmap.N)

# define the bins and normalize
#             bounds = np.linspace(0,20,21)
bounds = np.linspace(data_min_pl,data_max_pl,N_colors)
norm = matplotlib.colors.BoundaryNorm(bounds, cmap.N)

#             m.pcolormesh(x,y,data_new,shading='flat',cmap=plt.cm.jet,vmin=data_min_pl, vmax=data_max_pl)
m.pcolormesh(x,y,data,shading='flat',cmap=cmap, norm=norm)
m.colorbar(location='right')

# Add a coastline and axis values.

m.drawcoastlines()
#m.fillcontinents()
m.drawmapboundary()
m.drawparallels(np.arange(-90.,90.,10.),labels=[1,0,0,0])
m.drawmeridians(np.arange(-180.,180.,10.),labels=[0,0,0,1])
# Out:
# {0.0: ([<matplotlib.lines.Line2D at 0x2ba922fd00b8>],
#   [Text(40030.2,-400302,'0°')]),
#  10.0: ([<matplotlib.lines.Line2D at 0x2ba922f55f98>],
#   [Text(1.12084e+06,-400302,'10°E')]),
#  20.0: ([<matplotlib.lines.Line2D at 0x2ba922f53400>],
#   [Text(2.24169e+06,-400302,'20°E')]),
#  30.0: ([<matplotlib.lines.Line2D at 0x2ba922f53828>],
#   [Text(3.36253e+06,-400302,'30°E')]),
#  40.0: ([<matplotlib.lines.Line2D at 0x2ba922f53c50>],
#   [Text(4.48338e+06,-400302,'40°E')]),
#  50.0: ([<matplotlib.lines.Line2D at 0x2ba922f3d0b8>],
#   [Text(5.56419e+06,-400302,'50°E')]),
#  60.0: ([<matplotlib.lines.Line2D at 0x2ba922f3d4e0>],
#   [Text(6.68504e+06,-400302,'60°E')]),
#  70.0: ([<matplotlib.lines.Line2D at 0x2ba922f3d908>],
#   [Text(7.80588e+06,-400302,'70°E')]),
#  80.0: ([<matplotlib.lines.Line2D at 0x2ba922f3dd30>],
#   [Text(8.92672e+06,-400302,'80°E')]),
#  90.0: ([<matplotlib.lines.Line2D at 0x2ba922f68198>],
#   [Text(1.00476e+07,-400302,'90°E')]),
#  100.0: ([<matplotlib.lines.Line2D at 0x2ba922f685c0>],
#   [Text(1.11284e+07,-400302,'100°E')]),
#  110.0: ([<matplotlib.lines.Line2D at 0x2ba922f689e8>],
#   [Text(1.22492e+07,-400302,'110°E')]),
#  120.0: ([<matplotlib.lines.Line2D at 0x2ba922f68e10>],
#   [Text(1.33701e+07,-400302,'120°E')]),
#  130.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9c278>],
#   [Text(1.44909e+07,-400302,'130°E')]),
#  140.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9c6a0>],
#   [Text(1.55717e+07,-400302,'140°E')]),
#  150.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9cac8>],
#   [Text(1.66926e+07,-400302,'150°E')]),
#  160.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9cef0>],
#   [Text(1.78134e+07,-400302,'160°E')]),
#  170.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9e358>],
#   [Text(1.89343e+07,-400302,'170°E')]),
#  180.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9e780>],
#   [Text(2.00551e+07,-400302,'180°')]),
#  190.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9eba8>],
#   [Text(2.11359e+07,-400302,'170°W')]),
#  200.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9efd0>],
#   [Text(2.22568e+07,-400302,'160°W')]),
#  210.0: ([<matplotlib.lines.Line2D at 0x2ba92ab92438>],
#   [Text(2.33776e+07,-400302,'150°W')]),
#  220.0: ([<matplotlib.lines.Line2D at 0x2ba92ab92860>],
#   [Text(2.44985e+07,-400302,'140°W')]),
#  230.0: ([<matplotlib.lines.Line2D at 0x2ba92ab92c88>],
#   [Text(2.55793e+07,-400302,'130°W')]),
#  240.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9f0f0>],
#   [Text(2.67001e+07,-400302,'120°W')]),
#  250.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9f518>],
#   [Text(2.7821e+07,-400302,'110°W')]),
#  260.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9f940>],
#   [Text(2.89418e+07,-400302,'100°W')]),
#  270.0: ([<matplotlib.lines.Line2D at 0x2ba92ab9fd68>],
#   [Text(3.00626e+07,-400302,'90°W')]),
#  280.0: ([<matplotlib.lines.Line2D at 0x2ba92abae1d0>],
#   [Text(3.11435e+07,-400302,'80°W')]),
#  290.0: ([<matplotlib.lines.Line2D at 0x2ba92abae5f8>],
#   [Text(3.22643e+07,-400302,'70°W')]),
#  300.0: ([<matplotlib.lines.Line2D at 0x2ba92abaea20>],
#   [Text(3.33851e+07,-400302,'60°W')]),
#  310.0: ([<matplotlib.lines.Line2D at 0x2ba92abaee48>],
#   [Text(3.4506e+07,-400302,'50°W')]),
#  320.0: ([<matplotlib.lines.Line2D at 0x2ba92abba2b0>],
#   [Text(3.55868e+07,-400302,'40°W')]),
#  330.0: ([<matplotlib.lines.Line2D at 0x2ba92abba6d8>],
#   [Text(3.67077e+07,-400302,'30°W')]),
#  340.0: ([<matplotlib.lines.Line2D at 0x2ba92abbab00>],
#   [Text(3.78285e+07,-400302,'20°W')]),
#  350.0: ([<matplotlib.lines.Line2D at 0x2ba92abbaf28>],
#   [Text(3.89493e+07,-400302,'10°W')]),
#  360.0: ([<matplotlib.lines.Line2D at 0x2ba923f5f390>],
#   [Text(40030.2,-400302,'0°')])}

# %%
file = netCDF4.Dataset(url)
data.shape
# Out:
# (256, 512)
